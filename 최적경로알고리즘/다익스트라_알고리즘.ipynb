# %% [markdown]
# <a href="https://colab.research.google.com/github/namrmino/Algorithm_Python/blob/main/%EC%B5%9C%EC%A0%81%EA%B2%BD%EB%A1%9C%EC%95%8C%EA%B3%A0%EB%A6%AC%EC%A6%98/%EB%8B%A4%EC%9D%B5%EC%8A%A4%ED%8A%B8%EB%9D%BC_%EC%95%8C%EA%B3%A0%EB%A6%AC%EC%A6%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 다익스트라 알고리즘

# %%
import sys
input = sys.stdin.readline
INF = int(1e9) # 무한을 의미하는 값으로 10억을 설정

# 노드의 개수, 간선의 개수를 입력받기
n, m = map(int, input().split())
# 시작 노드 번호를 입력받기
start = int(input())
# 각 노드에 연결되어 있는 노드에 대한 정보를 담는 리스트를 만들기
graph = [[] for i in range(n + 1)]
# 방문한 적이 있는지 체크하는 목적의 리스트를 만들기
visited = [False] * (n + 1)
# 최단 거리 테이블을 모두 무한으로 초기화
distance = [INF] * (n + 1)

# 모든 간선 정보를 입력받기
for _ in range(m):
    a, b, c = map(int, input().split())
    # a번 노드에서 b번 노드로 가는 비용이 c라는 의미
    graph[a].append((b, c))

# 방문하지 않은 노드 중에서, 가장 최단 거리가 짧은 노드의 번호를 반환
def get_smallest_node():
    min_value = INF
    index = 0 # 가장 최단 거리가 짧은 노드(인덱스)
    for i in range(1, n + 1):
        if distance[i] < min_value and not visited[i]:
            min_value = distance[i]
            index = i
    return index

def dijkstra(start):
    # 시작 노드에 대해서 초기화
    distance[start] = 0
    visited[start] = True
    for j in graph[start]:
        distance[j[0]] = j[1]
    # 시작 노드를 제외한 전체 n - 1개의 노드에 대해 반복
    for i in range(n - 1):
        # 현재 최단 거리가 가장 짧은 노드를 꺼내서, 방문 처리
        now = get_smallest_node()
        visited[now] = True
        # 현재 노드와 연결된 다른 노드를 확인
        for j in graph[now]:
            cost = distance[now] + j[1]
            # 현재 노드를 거쳐서 다른 노드로 이동하는 거리가 더 짧은 경우
            if cost < distance[j[0]]:
                distance[j[0]] = cost

# 다익스트라 알고리즘을 수행
dijkstra(start)

# 모든 노드로 가기 위한 최단 거리를 출력
for i in range(1, n + 1):
    # 도달할 수 없는 경우, 무한(INFINITY)이라고 출력
    if distance[i] == INF:
        print("INFINITY")
    # 도달할 수 있는 경우 거리를 출력
    else:
        print(distance[i])

# %% [markdown]
# ### 지하철 길찾기 : 다익스트라 알고리즘 응용

# %%
line = \
{
 '1호선' : 1,
 '2호선' : 2,
 '3호선' : 3,
 '4호선' : 4,
 '5호선' : 5,
 '6호선' : 6,
 '7호선' : 7,
 '8호선' : 8,
 '9호선' : 9,
 '인천1호선' : 11,
 '인천2호선' : 12,
 '수인선' : 32,
 '서해선' : 31
}

# %%
station = {
    '계양': [ 
        10000, # 출발지에서 계양에 도착까지 걸린 시간
        [
            # 계양에서 갈 수 있는 역이름, 노선번호(line), 소요시간
            ['부평구청', 11, 17]
    
        ]
    ],
    '부평구청': [
        10000, # 출발지에서 부평구청에 도착까지 걸린 시간
        [
            # 부평구청에서 갈 수 있는 역이름, 노선번호, 소요시간
            ['부평', 11, 3],
            ['온수', 7, 18],
            ['계양', 11, 17]
        ]
    ],
    '구로': [
        10000, # 출발지에서 구로에 도착까지 걸린 시간
        [
            # 구로에서 갈 수 있는 역이름, 노선번호, 소요시간
            ['온수', 1, 10],
            ['가산디지털단지', 1, 5]
        ]
    ],
    '검암': [
        10000, # 출발지에서 검암에 도착까지 걸린 시간
        [
            # 검암에서 갈 수 있는 역이름, 노선번호, 소요시간
            ['주안', 12, 21]
        ]
    ],
    '부평': [
        10000, # 출발지에서 부평에 도착까지 걸린 시간
        [
            # 부평에서 갈 수 있는 역이름, 노선번호, 소요시간
            ['부평구청', 11, 3],
            ['주안', 1, 9],
            ['인천시청', 11, 9],
            ['소사', 1, 11]
        ]
    ],
    '온수': [
        10000, # 출발지에서 온수에 도착까지 걸린 시간
        [
            # 온수에서 갈 수 있는 역이름, 노선번호, 소요시간
            ['부평구청', 7, 18],
            ['구로', 1, 10],
            ['가산디지털단지', 7, 10],
            ['소사', 1, 5]
        ]
    ],
    '가산디지털단지': [
        10000, # 출발지에서 가산디지털단지에 도착까지 걸린 시간
        [
            # 가산디지털단지에서 갈 수 있는 역이름, 노선번호, 소요시간
            ['구로', 1, 5],
            ['온수', 7, 10],
            ['금정', 1, 18]
        ]
    ],
    '주안': [
        10000, # 출발지에서 주안에 도착까지 걸린 시간
        [
            # 주안에서 갈 수 있는 역이름, 노선번호, 소요시간
            ['검암', 12, 21],
            ['부평', 1, 9],
            ['인천', 1, 12],
            ['인천시청', 12, 5]
        ]
    ],
    '인천시청': [
        10000, # 출발지에서 인천시청에 도착까지 걸린 시간
        [
            # 인천시청에서 갈 수 있는 역이름, 노선번호, 소요시간
            ['주안', 12, 5],
            ['부평', 11, 9],
            ['운연', 12, 12]
        ]
    ],
    '소사': [
        10000, # 출발지에서 소사에 도착까지 걸린 시간
        [
            # 소사에서 갈 수 있는 역이름, 노선번호, 소요시간
            ['부평', 1, 11],
            ['온수', 1, 5],
            ['초지', 31, 27]
        ]
    ],
    '금정': [
        10000, # 출발지에서 금정에 도착까지 걸린 시간
        [
            # 금정에서 갈 수 있는 역이름, 노선번호, 소요시간
            ['가산디지털단지', 1, 18],
            ['초지', 4, 25]
        ]
    ],
    '인천': [
        10000, # 출발지에서 인천에 도착까지 걸린 시간
        [
            # 인천에서 갈 수 있는 역이름, 노선번호, 소요시간
            ['주안', 1, 12],
            ['원인재', 32, 15]
        ]
    ],
    '원인재': [
        10000, # 출발지에서 원인재에 도착까지 걸린 시간
        [
            # 원인재에서 갈 수 있는 역이름, 노선번호, 소요시간
            ['오이도', 32, 15],
            ['인천', 32, 15],
            ['국제업무지구', 11, 16]
        ]
    ],
    '운연': [
        10000, # 출발지에서 운연에 도착까지 걸린 시간
        [
            # 운연에서 갈 수 있는 역이름, 노선번호, 소요시간
            ['인천시청', 12, 12]
        ]
    ],
    '초지': [
        10000, # 출발지에서 초지에 도착까지 걸린 시간
        [
            # 초지에서 갈 수 있는 역이름, 노선번호, 소요시간
            ['소사', 31, 27],
            ['오이도', 4, 12],
            ['금정', 4, 25],
            ['원시', 32, 5]
        ]
    ],
    '국제업무지구': [
        10000, # 출발지에서 국제업무지구에 도착까지 걸린 시간
        [
            # 국제업무지구에서 갈 수 있는 역이름, 노선번호, 소요시간
            ['원인재', 11, 16]
        ]
    ],
    '오이도': [
        10000, # 출발지에서 오이도에 도착까지 걸린 시간
        [
            # 오이도에서 갈 수 있는 역이름, 노선번호, 소요시간
            ['원인재', 32, 15],
            ['초지', 4, 12]
        ]
    ],
    '원시': [
        10000, # 출발지에서 원시에 도착까지 걸린 시간
        [
            # 원시에서 갈 수 있는 역이름, 노선번호, 소요시간
            ['초지', 31, 5]
        ]
    ]
}

# %%
def search(dir, stops, end, Line, time=0):
  if station[stops][0] > time:
    station[stops][0] = time
    dir.append(stops)
  else:
    return '취소'

  if stops == end:
    print(time)
    print(dir)
    return '도착'

  for i in station[stops][1]:
    trans = 0 if Line == i[1] else 5 # 환승시간 : 5분으로 통일
    search(list(dir), i[0], end, i[1], i[2]+trans+time)

search([], '부평', '구로', line['수인선'])
# Out:
# 46
# ['부평', '부평구청', '온수', '구로']
# 31
# ['부평', '소사', '온수', '구로']
